# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df1= pd.read_csv("mencase.csv")
df2=pd.read_csv("checklstm.csv")
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))
df2=scaler.fit_transform(np.array(df2).reshape(-1,1))
cases=df1
hosp=df2[0:142]
#print(cases)
cases =cases.reshape(142,1, 1)

# %%
# Out:
# Creating Model
# Training
# Epoch 0 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 2s 14ms/step - loss: 0.0338 - val_loss: 0.0342
# Time took 0.0 min
# Previous memory state states[0] = [[-0.12657149  0.05038553]]
# Previous carry state states[1] = [[-0.24873017  0.10394534]]
# Input
# bias_i = [ 0.03297098 -0.03423794]
# kernel_i = [[ 0.04733294 -0.1001077 ]]
# recurrent_kernel_i = [[-0.12736118  0.55095255]
#  [-0.72884375 -0.09236627]]
# Forget
# bias_f = [1.0329226  0.96782786]
# kernel_f = [[ 3.8507162e-05 -2.2658252e-03]]
# recurrent_kernel_f = [[ 0.45858905  0.29087546]
#  [-0.42485225  0.01643309]]
# Cell
# bias_c = [-0.03046925 -0.03022432]
# kernel_c = [[-0.4347333   0.09755191]]
# recurrent_kernel_c = [[ 0.09071183 -0.42313308]
#  [ 0.21257403 -0.09433118]]
# Output
# bias_o = [ 0.03290056 -0.03218275]
# kernel_o = [[0.10321861 0.00601527]]
# recurrent_kernel_o = [[-0.4487943   0.19077794]
#  [-0.32945353 -0.16450918]]
# output = [-0.09583154  0.03908643]
# Epoch 1 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 4ms/step - loss: 0.0314 - val_loss: 0.0352
# Time took 0.0 min
# Previous memory state states[0] = [[-0.1247948   0.04197742]]
# Previous carry state states[1] = [[-0.24530075  0.08666179]]
# Input
# bias_i = [ 0.04336572 -0.04661004]
# kernel_i = [[ 0.01244535 -0.00490214]]
# recurrent_kernel_i = [[-0.13713899  0.5624642 ]
#  [-0.7197641  -0.10201408]]
# Forget
# bias_f = [1.036715   0.96405464]
# kernel_f = [[ 0.00618297 -0.00174495]]
# recurrent_kernel_f = [[ 0.45326966  0.29604143]
#  [-0.41958463  0.01108346]]
# Cell
# bias_c = [-0.03268379 -0.032598  ]
# kernel_c = [[-0.3991309   0.07155427]]
# recurrent_kernel_c = [[ 0.0946865  -0.41908178]
#  [ 0.20842975 -0.09849623]]
# Output
# bias_o = [ 0.03670114 -0.03594256]
# kernel_o = [[ 0.05673451 -0.00255916]]
# recurrent_kernel_o = [[-0.45411345  0.19592984]
#  [-0.32419062 -0.16984816]]
# output = [-0.0962719  0.0325236]
# Epoch 2 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 1s 4ms/step - loss: 0.0309 - val_loss: 0.0305
# Time took 0.0 min
# Previous memory state states[0] = [[-0.11480028  0.03737132]]
# Previous carry state states[1] = [[-0.22595677  0.07668976]]
# Input
# bias_i = [ 0.04894057 -0.04899047]
# kernel_i = [[0.00133943 0.00146652]]
# recurrent_kernel_i = [[-0.14009978  0.5635733 ]
#  [-0.72549313 -0.0995312 ]]
# Forget
# bias_f = [1.0351428 0.972257 ]
# kernel_f = [[0.00205758 0.0012812 ]]
# recurrent_kernel_f = [[ 0.45499864  0.28916392]
#  [-0.42684144  0.01741086]]
# Cell
# bias_c = [-0.03021571 -0.03025136]
# kernel_c = [[-0.36253256  0.05257909]]
# recurrent_kernel_c = [[ 0.0926896  -0.4210671 ]
#  [ 0.21685065 -0.09000309]]
# Output
# bias_o = [ 0.03515805 -0.02775479]
# kernel_o = [[0.02623786 0.00232537]]
# recurrent_kernel_o = [[-0.45240867  0.18904142]
#  [-0.3314276  -0.16330625]]
# output = [-0.08873456  0.02923809]
# Epoch 3 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0310 - val_loss: 0.0358
# Time took 0.0 min
# Previous memory state states[0] = [[-0.11670591  0.0289287 ]]
# Previous carry state states[1] = [[-0.22902669  0.05952038]]
# Input
# bias_i = [ 0.06195376 -0.06163962]
# kernel_i = [[ 0.00640793 -0.00194577]]
# recurrent_kernel_i = [[-0.1523294   0.5716217 ]
#  [-0.7147932  -0.09214558]]
# Forget
# bias_f = [1.0403554 0.9641379]
# kernel_f = [[ 0.00826388 -0.00227815]]
# recurrent_kernel_f = [[ 0.44917572  0.29430246]
#  [-0.4216264   0.02692803]]
# Cell
# bias_c = [-0.03314875 -0.03341216]
# kernel_c = [[-0.33355206  0.02658411]]
# recurrent_kernel_c = [[ 0.09780238 -0.4157599 ]
#  [ 0.20870791 -0.09828392]]
# Output
# bias_o = [ 0.04047649 -0.03583946]
# kernel_o = [[ 0.0192233  -0.00334494]]
# recurrent_kernel_o = [[-0.4583109   0.19416659]
#  [-0.32615504 -0.1537127 ]]
# output = [-0.09186137  0.02274574]
# Epoch 4 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0306 - val_loss: 0.0351
# Time took 0.0 min
# Previous memory state states[0] = [[-0.11138432  0.02453925]]
# Previous carry state states[1] = [[-0.21846604  0.05018913]]
# Input
# bias_i = [ 0.07058738 -0.05723386]
# kernel_i = [[ 0.00392907 -0.00136224]]
# recurrent_kernel_i = [[-0.15938535  0.5639687 ]
#  [-0.726452   -0.09840133]]
# Forget
# bias_f = [1.0399634 0.9748567]
# kernel_f = [[ 0.00689594 -0.00241526]]
# recurrent_kernel_f = [[ 0.44930133  0.28307763]
#  [-0.43276724  0.01803992]]
# Cell
# bias_c = [-0.03241964 -0.03276783]
# kernel_c = [[-0.3076542   0.00829297]]
# recurrent_kernel_c = [[ 0.09735566 -0.41616258]
#  [ 0.21923716 -0.08762414]]
# Output
# bias_o = [ 0.04009197 -0.02511767]
# kernel_o = [[ 0.01490544 -0.00367027]]
# recurrent_kernel_o = [[-0.45818704  0.18290165]
#  [-0.3373559  -0.16243176]]
# output = [-0.08805489  0.0196042 ]
# Epoch 5 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 2ms/step - loss: 0.0306 - val_loss: 0.0389
# Time took 0.0 min
# Previous memory state states[0] = [[-0.11381245  0.01861692]]
# Previous carry state states[1] = [[-0.22256425  0.0382232 ]]
# Input
# bias_i = [ 0.0802325  -0.05097036]
# kernel_i = [[ 0.00174678 -0.00105565]]
# recurrent_kernel_i = [[-0.16784233  0.554982  ]
#  [-0.7206575  -0.09149698]]
# Forget
# bias_f = [1.0455734 0.9644485]
# kernel_f = [[ 0.00473731 -0.00196574]]
# recurrent_kernel_f = [[ 0.44358465  0.29105338]
#  [-0.42469266  0.02513293]]
# Cell
# bias_c = [-0.03579822 -0.03633611]
# kernel_c = [[-0.28747478 -0.00512686]]
# recurrent_kernel_c = [[ 0.10282265 -0.41060343]
#  [ 0.20847462 -0.09827018]]
# Output
# bias_o = [ 0.04581355 -0.03554056]
# kernel_o = [[ 0.01194252 -0.00198647]]
# recurrent_kernel_o = [[-0.46398634  0.19105355]
#  [-0.32926473 -0.1545099 ]]
# output = [-0.09152202  0.01478536]
# Epoch 6 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 1s 4ms/step - loss: 0.0297 - val_loss: 0.0320
# Time took 0.0 min
# Previous memory state states[0] = [[-0.10446311  0.01667584]]
# Previous carry state states[1] = [[-0.2040985   0.03441292]]
# Input
# bias_i = [ 0.0821737  -0.06938747]
# kernel_i = [[-0.00111221 -0.00035373]]
# recurrent_kernel_i = [[-0.17175516  0.5712191 ]
#  [-0.71268934 -0.07865136]]
# Forget
# bias_f = [1.0452945  0.95107883]
# kernel_f = [[ 0.00194191 -0.00030361]]
# recurrent_kernel_f = [[ 0.4407325   0.30241007]
#  [-0.41320243  0.03794352]]
# Cell
# bias_c = [-0.03113886 -0.03182654]
# kernel_c = [[-0.26397172 -0.01058238]]
# recurrent_kernel_c = [[ 0.10250635 -0.41083184]
#  [ 0.19495216 -0.11167758]]
# Output
# bias_o = [ 0.04551782 -0.04964807]
# kernel_o = [[ 0.00787104 -0.00076245]]
# recurrent_kernel_o = [[-0.466883    0.20244458]
#  [-0.31778762 -0.14132228]]
# output = [-0.0837058   0.01353436]
# Epoch 7 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0298 - val_loss: 0.0278
# Time took 0.0 min
# Previous memory state states[0] = [[-0.0965172   0.01466887]]
# Previous carry state states[1] = [[-0.18853323  0.03027456]]
# Input
# bias_i = [ 0.08568204 -0.07454953]
# kernel_i = [[-0.00099273 -0.00059703]]
# recurrent_kernel_i = [[-0.17536612  0.575358  ]
#  [-0.71587646 -0.07728626]]
# Forget
# bias_f = [1.0439345  0.94810253]
# kernel_f = [[ 0.00115038 -0.00055026]]
# recurrent_kernel_f = [[ 0.44036216  0.30401117]
#  [-0.41155696  0.03984835]]
# Cell
# bias_c = [-0.02766743 -0.0284752 ]
# kernel_c = [[-0.24363585 -0.0185349 ]]
# recurrent_kernel_c = [[ 0.10111319 -0.41216746]
#  [ 0.191853   -0.11466622]]
# Output
# bias_o = [ 0.04437944 -0.05211005]
# kernel_o = [[ 0.00593165 -0.00085229]]
# recurrent_kernel_o = [[-0.4674757   0.20346555]
#  [-0.31630498 -0.13993847]]
# output = [-0.07709817  0.0122386 ]
# Epoch 8 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0301 - val_loss: 0.0332
# Time took 0.0 min
# Previous memory state states[0] = [[-0.10156541  0.00946149]]
# Previous carry state states[1] = [[-0.19783503  0.01942276]]
# Input
# bias_i = [ 0.09789284 -0.06090229]
# kernel_i = [[0.00287128 0.00059493]]
# recurrent_kernel_i = [[-0.18475418  0.56466335]
#  [-0.7306931  -0.09054644]]
# Forget
# bias_f = [1.0491157 0.9601261]
# kernel_f = [[0.00482228 0.00109731]]
# recurrent_kernel_f = [[ 0.4354097   0.29342255]
#  [-0.42220622  0.02651707]]
# Cell
# bias_c = [-0.03283735 -0.0338089 ]
# kernel_c = [[-0.23040238 -0.03247007]]
# recurrent_kernel_c = [[ 0.10621891 -0.40696207]
#  [ 0.20386524 -0.10260418]]
# Output
# bias_o = [ 0.0496399  -0.04091778]
# kernel_o = [[0.00890259 0.0024901 ]]
# recurrent_kernel_o = [[-0.47247347  0.19344798]
#  [-0.32703918 -0.15287077]]
# output = [-0.08271123  0.00798789]
# Epoch 9 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0303 - val_loss: 0.0328
# Time took 0.0 min
# Previous memory state states[0] = [[-0.09840666  0.00649135]]
# Previous carry state states[1] = [[-0.19135478  0.01332384]]
# Input
# bias_i = [ 0.10421738 -0.05425907]
# kernel_i = [[0.00367904 0.00184818]]
# recurrent_kernel_i = [[-0.19215463  0.55606115]
#  [-0.73332614 -0.09179913]]
# Forget
# bias_f = [1.0513718 0.9587919]
# kernel_f = [[0.00658032 0.00300262]]
# recurrent_kernel_f = [[ 0.43164176  0.29268745]
#  [-0.42292267  0.02948368]]
# Cell
# bias_c = [-0.03276756 -0.03381628]
# kernel_c = [[-0.21165644 -0.03959514]]
# recurrent_kernel_c = [[ 0.10843524 -0.4046726 ]
#  [ 0.20250657 -0.10394778]]
# Output
# bias_o = [ 0.05196569 -0.04220859]
# kernel_o = [[0.00988377 0.00308099]]
# recurrent_kernel_o = [[-0.47631538  0.1927357 ]
#  [-0.32780176 -0.14986365]]
# output = [-0.08071461  0.00566142]
# Epoch 10 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 2ms/step - loss: 0.0298 - val_loss: 0.0278
# Time took 0.0 min
# Previous memory state states[0] = [[-0.0907034   0.00547397]]
# Previous carry state states[1] = [[-0.1765354   0.01124201]]
# Input
# bias_i = [ 0.10663772 -0.04897118]
# kernel_i = [[0.00255134 0.00051856]]
# recurrent_kernel_i = [[-0.19383143  0.55074066]
#  [-0.7348404  -0.0935702 ]]
# Forget
# bias_f = [1.0484741  0.95604944]
# kernel_f = [[0.00410777 0.00062244]]
# recurrent_kernel_f = [[ 0.43445602  0.29460016]
#  [-0.42102426  0.03310662]]
# Cell
# bias_c = [-0.02914311 -0.0302783 ]
# kernel_c = [[-0.19797862 -0.04444781]]
# recurrent_kernel_c = [[ 0.10548617 -0.40755427]
#  [ 0.19972618 -0.10669222]]
# Output
# bias_o = [ 0.04907945 -0.04494602]
# kernel_o = [[0.00797098 0.0014068 ]]
# recurrent_kernel_o = [[-0.47350705  0.19465336]
#  [-0.3259056  -0.14619903]]
# output = [-0.0740595   0.00514307]
# Epoch 11 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 2ms/step - loss: 0.0302 - val_loss: 0.0308
# Time took 0.0 min
# Previous memory state states[0] = [[-0.09387244  0.00219398]]
# Previous carry state states[1] = [[-0.18239158  0.00449211]]
# Input
# bias_i = [ 0.11570714 -0.03718456]
# kernel_i = [[0.00036774 0.0003632 ]]
# recurrent_kernel_i = [[-0.20130455  0.54097784]
#  [-0.74491704 -0.10500994]]
# Forget
# bias_f = [1.051717 0.962969]
# kernel_f = [[0.00318385 0.0009542 ]]
# recurrent_kernel_f = [[ 0.43086687  0.2881067 ]
#  [-0.4275281   0.02408219]]
# Cell
# bias_c = [-0.0321195 -0.0333729]
# kernel_c = [[-0.19086935 -0.05272068]]
# recurrent_kernel_c = [[ 0.10868416 -0.40428677]
#  [ 0.20661226 -0.0997428 ]]
# Output
# bias_o = [ 0.05234571 -0.03802897]
# kernel_o = [[0.00781168 0.00066568]]
# recurrent_kernel_o = [[-0.47711042  0.18815668]
#  [-0.33242086 -0.15526524]]
# output = [-0.07756673  0.00248582]
# Epoch 12 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0296 - val_loss: 0.0300
# Time took 0.0 min
# Previous memory state states[0] = [[-0.09001575  0.00125257]]
# Previous carry state states[1] = [[-0.17479374  0.00256207]]
# Input
# bias_i = [ 0.11977119 -0.03470454]
# kernel_i = [[ 0.00084256 -0.00066181]]
# recurrent_kernel_i = [[-0.2063839   0.5371027 ]
#  [-0.7494021  -0.10726579]]
# Forget
# bias_f = [1.0525048 0.9643528]
# kernel_f = [[3.073139e-03 7.189810e-05]]
# recurrent_kernel_f = [[ 0.42852443  0.2851629 ]
#  [-0.4304527   0.02082935]]
# Cell
# bias_c = [-0.03052767 -0.03183818]
# kernel_c = [[-0.18000989 -0.05562009]]
# recurrent_kernel_c = [[ 0.10942186 -0.4035005 ]
#  [ 0.20794077 -0.09839987]]
# Output
# bias_o = [ 0.05306499 -0.03679071]
# kernel_o = [[0.00733549 0.00030007]]
# recurrent_kernel_o = [[-0.4794446   0.1852408 ]
#  [-0.33526522 -0.15836671]]
# output = [-0.07443175  0.00183929]
# Epoch 13 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0301 - val_loss: 0.0319
# Time took 0.0 min
# Previous memory state states[0] = [[-0.09290177 -0.00162523]]
# Previous carry state states[1] = [[-0.17995523 -0.00331469]]
# Input
# bias_i = [ 0.12667845 -0.02801596]
# kernel_i = [[0.00447895 0.00035468]]
# recurrent_kernel_i = [[-0.21356228  0.5318522 ]
#  [-0.7573614  -0.11447937]]
# Forget
# bias_f = [1.0567799 0.9701919]
# kernel_f = [[0.00747132 0.00151246]]
# recurrent_kernel_f = [[ 0.42207733  0.2786802 ]
#  [-0.4369067   0.0130639 ]]
# Cell
# bias_c = [-0.03342588 -0.03476033]
# kernel_c = [[-0.17118846 -0.06026283]]
# recurrent_kernel_c = [[ 0.11372548 -0.39921793]
#  [ 0.21376976 -0.09256864]]
# Output
# bias_o = [ 0.05735037 -0.03094948]
# kernel_o = [[0.01066311 0.00346486]]
# recurrent_kernel_o = [[-0.48589566  0.17875105]
#  [-0.3417228  -0.16614088]]
# output = [-0.07774776 -0.00058974]
# Epoch 14 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 2ms/step - loss: 0.0294 - val_loss: 0.0283
# Time took 0.0 min
# Previous memory state states[0] = [[-0.08675768 -0.0016641 ]]
# Previous carry state states[1] = [[-0.16812266 -0.00338822]]
# Input
# bias_i = [ 0.13067146 -0.01965398]
# kernel_i = [[0.004774   0.00312239]]
# recurrent_kernel_i = [[-0.21804677  0.5235013 ]
#  [-0.76484764 -0.12465478]]
# Forget
# bias_f = [1.0553653 0.9726133]
# kernel_f = [[0.00616236 0.00332403]]
# recurrent_kernel_f = [[ 0.42160836  0.2748066 ]
#  [-0.44074315  0.00635682]]
# Cell
# bias_c = [-0.02970272 -0.03114695]
# kernel_c = [[-0.16312669 -0.06317451]]
# recurrent_kernel_c = [[ 0.11230214 -0.40053967]
#  [ 0.21613161 -0.09011418]]
# Output
# bias_o = [ 0.05595478 -0.02854763]
# kernel_o = [[0.00954296 0.0044295 ]]
# recurrent_kernel_o = [[-0.4863798   0.17489173]
#  [-0.3455731  -0.1728488 ]]
# output = [-0.07218657 -0.00031217]
# Epoch 15 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0293 - val_loss: 0.0340
# Time took 0.0 min
# Previous memory state states[0] = [[-0.09353726 -0.00467168]]
# Previous carry state states[1] = [[-0.18058541 -0.0094954 ]]
# Input
# bias_i = [ 0.14040715 -0.00966151]
# kernel_i = [[4.8339241e-03 2.5056564e-05]]
# recurrent_kernel_i = [[-0.22905152  0.5124126 ]
#  [-0.77294064 -0.13247044]]
# Forget
# bias_f = [1.0624336  0.97692794]
# kernel_f = [[0.00864047 0.00046654]]
# recurrent_kernel_f = [[ 0.41247186  0.26809815]
#  [-0.44742802  0.00250733]]
# Cell
# bias_c = [-0.03366789 -0.03514178]
# kernel_c = [[-0.16011126 -0.07050187]]
# recurrent_kernel_c = [[ 0.11935698 -0.39345738]
#  [ 0.22040722 -0.08582278]]
# Output
# bias_o = [ 0.06313922 -0.02402018]
# kernel_o = [[0.01364356 0.00299349]]
# recurrent_kernel_o = [[-0.4956031   0.1680241 ]
#  [-0.35235047 -0.1768512 ]]
# output = [-0.07884032 -0.00280019]
# Epoch 16 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0296 - val_loss: 0.0339
# Time took 0.0 min
# Previous memory state states[0] = [[-0.09304268 -0.00610511]]
# Previous carry state states[1] = [[-0.17957948 -0.01239505]]
# Input
# bias_i = [ 0.14514261 -0.0018409 ]
# kernel_i = [[0.00409814 0.00174625]]
# recurrent_kernel_i = [[-0.23291598  0.5054027 ]
#  [-0.77785206 -0.13942492]]
# Forget
# bias_f = [1.0630567 0.9790053]
# kernel_f = [[0.00627888 0.00245694]]
# recurrent_kernel_f = [[ 4.1211271e-01  2.6628760e-01]
#  [-4.4926193e-01 -1.7929060e-04]]
# Cell
# bias_c = [-0.03371243 -0.03522144]
# kernel_c = [[-0.15543656 -0.07472716]]
# recurrent_kernel_c = [[ 0.11995064 -0.39284047]
#  [ 0.22247146 -0.08374579]]
# Output
# bias_o = [ 0.06377307 -0.02193948]
# kernel_o = [[0.01086187 0.00361945]]
# recurrent_kernel_o = [[-0.495967    0.16621687]
#  [-0.35418484 -0.17952932]]
# output = [-0.07865806 -0.00384851]
# Epoch 17 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0299 - val_loss: 0.0351
# Time took 0.0 min
# Previous memory state states[0] = [[-0.09310897 -0.0074894 ]]
# Previous carry state states[1] = [[-0.1795815  -0.01519391]]
# Input
# bias_i = [0.15077789 0.0077303 ]
# kernel_i = [[0.00397863 0.00237774]]
# recurrent_kernel_i = [[-0.23823221  0.49773756]
#  [-0.7826403  -0.14673236]]
# Forget
# bias_f = [1.0641935 0.9804594]
# kernel_f = [[0.00647041 0.00306056]]
# recurrent_kernel_f = [[ 0.4099772   0.26459014]
#  [-0.4509257  -0.00148304]]
# Cell
# bias_c = [-0.03425332 -0.03585607]
# kernel_c = [[-0.15011951 -0.07782297]]
# recurrent_kernel_c = [[ 0.12095157 -0.39178094]
#  [ 0.2237582  -0.08238703]]
# Output
# bias_o = [ 0.06493853 -0.0204815 ]
# kernel_o = [[0.01043765 0.0037245 ]]
# recurrent_kernel_o = [[-0.49812555  0.164514  ]
#  [-0.3558695  -0.18082814]]
# output = [-0.07904254 -0.00495479]
# Epoch 18 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0306 - val_loss: 0.0328
# Time took 0.0 min
# Previous memory state states[0] = [[-0.08930394 -0.00772432]]
# Previous carry state states[1] = [[-0.17247573 -0.0156678 ]]
# Input
# bias_i = [0.15470132 0.01872971]
# kernel_i = [[ 0.00203249 -0.00067666]]
# recurrent_kernel_i = [[-0.24027157  0.48920116]
#  [-0.78751135 -0.15734488]]
# Forget
# bias_f = [1.0609376  0.98065275]
# kernel_f = [[0.00478685 0.00018913]]
# recurrent_kernel_f = [[ 0.41425225  0.26599148]
#  [-0.44955546 -0.00361535]]
# Cell
# bias_c = [-0.03207714 -0.03380629]
# kernel_c = [[-0.14703129 -0.08123383]]
# recurrent_kernel_c = [[ 0.1175832  -0.39503384]
#  [ 0.22387543 -0.08215784]]
# Output
# bias_o = [ 0.06171279 -0.02029395]
# kernel_o = [[0.00936    0.00191501]]
# recurrent_kernel_o = [[-0.49387902  0.1659231 ]
#  [-0.35452002 -0.18295132]]
# output = [-0.07550918 -0.00490985]
# Epoch 19 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0298 - val_loss: 0.0323
# Time took 0.0 min
# Previous memory state states[0] = [[-0.08868778 -0.00847579]]
# Previous carry state states[1] = [[-0.17124675 -0.01716971]]
# Input
# bias_i = [0.15939346 0.02763933]
# kernel_i = [[0.00321767 0.00139142]]
# recurrent_kernel_i = [[-0.24449545  0.4815061 ]
#  [-0.7931462  -0.1658309 ]]
# Forget
# bias_f = [1.0610224 0.9830853]
# kernel_f = [[0.0052864  0.00182745]]
# recurrent_kernel_f = [[ 0.41378263  0.26367465]
#  [-0.45187807 -0.00764817]]
# Cell
# bias_c = [-0.03161656 -0.03341567]
# kernel_c = [[-0.14443885 -0.08415458]]
# recurrent_kernel_c = [[ 0.11760537 -0.39495715]
#  [ 0.2262514  -0.07973108]]
# Output
# bias_o = [ 0.06182332 -0.01785366]
# kernel_o = [[0.0096029  0.00331923]]
# recurrent_kernel_o = [[-0.49436772  0.16359884]
#  [-0.3568609  -0.18699475]]
# output = [-0.07501183 -0.00538984]
# Epoch 20 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0294 - val_loss: 0.0293
# Time took 0.0 min
# Previous memory state states[0] = [[-0.08317428 -0.00783409]]
# Previous carry state states[1] = [[-0.16071232 -0.01586545]]
# Input
# bias_i = [0.1608697  0.03172469]
# kernel_i = [[0.0023467  0.00199657]]
# recurrent_kernel_i = [[-0.24624537  0.4775911 ]
#  [-0.7953604  -0.16967763]]
# Forget
# bias_f = [1.0597045 0.9828795]
# kernel_f = [[0.00357034 0.00209687]]
# recurrent_kernel_f = [[ 0.41408527  0.26309824]
#  [-0.45245066 -0.00871109]]
# Cell
# bias_c = [-0.02865314 -0.03046856]
# kernel_c = [[-0.1384565 -0.082941 ]]
# recurrent_kernel_c = [[ 0.11627312 -0.39628243]
#  [ 0.22602591 -0.07995596]]
# Output
# bias_o = [ 0.06057514 -0.01794333]
# kernel_o = [[0.00718777 0.0024082 ]]
# recurrent_kernel_o = [[-0.49411243  0.16294347]
#  [-0.35748044 -0.18813466]]
# output = [-0.07003541 -0.00474065]
# Epoch 21 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0300 - val_loss: 0.0324
# Time took 0.0 min
# Previous memory state states[0] = [[-0.08801217 -0.00948856]]
# Previous carry state states[1] = [[-0.16974092 -0.0191774 ]]
# Input
# bias_i = [0.1694927 0.0460236]
# kernel_i = [[0.0043237  0.00235946]]
# recurrent_kernel_i = [[-0.25459078  0.46343547]
#  [-0.80479836 -0.18343447]]
# Forget
# bias_f = [1.0628655  0.98755515]
# kernel_f = [[0.00634976 0.00286249]]
# recurrent_kernel_f = [[ 0.41075206  0.25806975]
#  [-0.45749623 -0.01510806]]
# Cell
# bias_c = [-0.03039583 -0.0322905 ]
# kernel_c = [[-0.14085479 -0.08989426]]
# recurrent_kernel_c = [[ 0.11934593 -0.3931232 ]
#  [ 0.2306316  -0.07527934]]
# Output
# bias_o = [ 0.06375559 -0.01327034]
# kernel_o = [[0.01074552 0.00417858]]
# recurrent_kernel_o = [[-0.49746397  0.15791786]
#  [-0.36254397 -0.1945425 ]]
# output = [-0.07439253 -0.00591855]
# Epoch 22 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0301 - val_loss: 0.0396
# Time took 0.0 min
# Previous memory state states[0] = [[-0.0940882  -0.01127836]]
# Previous carry state states[1] = [[-0.18113041 -0.02275008]]
# Input
# bias_i = [0.17770077 0.05887864]
# kernel_i = [[0.00373003 0.00054333]]
# recurrent_kernel_i = [[-0.26215145  0.4515034 ]
#  [-0.81224453 -0.19371071]]
# Forget
# bias_f = [1.066506   0.99268246]
# kernel_f = [[0.00688584 0.00183115]]
# recurrent_kernel_f = [[ 0.40724444  0.25337282]
#  [-0.46220893 -0.0202019 ]]
# Cell
# bias_c = [-0.03343178 -0.03540481]
# kernel_c = [[-0.14207368 -0.09465612]]
# recurrent_kernel_c = [[ 0.1229021  -0.3894911 ]
#  [ 0.23569989 -0.07015637]]
# Output
# bias_o = [ 0.06743    -0.00813198]
# kernel_o = [[0.01191523 0.0038985 ]]
# recurrent_kernel_o = [[-0.5010018   0.15320937]
#  [-0.3672835  -0.19965468]]
# output = [-0.0800982  -0.00741666]
# Epoch 23 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 3ms/step - loss: 0.0300 - val_loss: 0.0271
# Time took 0.0 min
# Previous memory state states[0] = [[-0.07964668 -0.00886629]]
# Previous carry state states[1] = [[-0.15397567 -0.01791948]]
# Input
# bias_i = [0.17487587 0.0615046 ]
# kernel_i = [[0.00066865 0.00059801]]
# recurrent_kernel_i = [[-0.25771305  0.45081976]
#  [-0.8094725  -0.19511221]]
# Forget
# bias_f = [1.0582697  0.98712665]
# kernel_f = [[0.00159853 0.00056783]]
# recurrent_kernel_f = [[ 0.4160754   0.2603971 ]
#  [-0.45522305 -0.0154099 ]]
# Cell
# bias_c = [-0.02611749 -0.02818927]
# kernel_c = [[-0.13322029 -0.08900692]]
# recurrent_kernel_c = [[ 0.11459608 -0.39771366]
#  [ 0.23012495 -0.07565455]]
# Output
# bias_o = [ 0.05922265 -0.01368813]
# kernel_o = [[0.00528917 0.00064786]]
# recurrent_kernel_o = [[-0.49219322  0.16023849]
#  [-0.36031362 -0.19484784]]
# output = [-0.06681382 -0.00520101]
# Epoch 24 / 25
# Train on 127 samples, validate on 15 samples
# Epoch 1/1
# 127/127 [==============================] - 0s 4ms/step - loss: 0.0297 - val_loss: 0.0370
# Time took 0.0 min
# Previous memory state states[0] = [[-0.09200368 -0.01218717]]
# Previous carry state states[1] = [[-0.17709197 -0.02454151]]
# Input
# bias_i = [0.1862965  0.07586849]
# kernel_i = [[0.00645891 0.00433657]]
# recurrent_kernel_i = [[-0.26896596  0.43672907]
#  [-0.82027197 -0.20728596]]
# Forget
# bias_f = [1.066243  0.9955908]
# kernel_f = [[0.00871282 0.00472665]]
# recurrent_kernel_f = [[ 0.40788484  0.25161386]
#  [-0.4640089  -0.02398436]]
# Cell
# bias_c = [-0.03279243 -0.03490799]
# kernel_c = [[-0.13558167 -0.09506421]]
# recurrent_kernel_c = [[ 0.12249665 -0.3897647 ]
#  [ 0.2385275  -0.06722535]]
# Output
# bias_o = [ 0.06725984 -0.00514757]
# kernel_o = [[0.01246079 0.00646484]]
# recurrent_kernel_o = [[-0.50044876  0.15137352]
#  [-0.36916247 -0.20351337]]
# output = [-0.07847773 -0.00811713]
# Predicting
# Ploting Results

# %%
import matplotlib.pyplot as plt

labels = ["loss","val_loss"]
for lab in labels:
    plt.plot(model.history[lab],label=lab + " model")
plt.yscale("log")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-61f2aaf60115> in <module>
#       3 labels = ["loss","val_loss"]
#       4 for lab in labels:
# ----> 5     plt.plot(model.history[lab],label=lab + " model")
#       6 plt.yscale("log")
#       7 plt.legend()
#
# AttributeError: 'Sequential' object has no attribute 'history'

# %%
len_ts = X_train.shape[1]
print(len_ts)
# Out:
# 1

# %%
from keras import models 
from keras import layers
from keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %%
hunits = 40
model1, _ = define_model(
    hidden_neurons = hunits,
    len_ts = X_train.shape[1])
model1.summary()


import sys, time
import numpy as np

w_train= np.zeros((120, 1))
w_train[60:] = 1


# In[33]:


from keras.callbacks import ModelCheckpoint
start = time.time()
hist1 = model1.fit(X_train, y_train, 
                   batch_size=2**9,
                   epochs=75, 
                   verbose=False,
                   sample_weight=w_train,
                   
                   validation_split= 0.10,
                   callbacks=[
                   ModelCheckpoint(filepath="weights{epoch:03d}.hdf5")])
end = time.time()
print("Time took {:3.1f} min".format((end-start)/60))
# Out:
# WARNING:tensorflow:From C:\Users\Hafsa\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:504: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Hafsa\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:68: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Hafsa\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:126: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\Hafsa\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3135: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\Hafsa\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3828: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\Hafsa\Anaconda3\lib\site-packages\keras\optimizers.py:744: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 1, 1)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1)              0
# _________________________________________________________________
# RNN (LSTM)                   (None, 1, 40)             6720
# _________________________________________________________________
# nextt (LSTM)                 (None, 1, 40)             12960
# _________________________________________________________________
# other (LSTM)                 (None, 1, 40)             12960
# _________________________________________________________________
# otherr (LSTM)                (None, 1, 40)             12960
# _________________________________________________________________
# otherrr (LSTM)               (None, 1, 40)             12960
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 1, 1)              41
# =================================================================
# Total params: 58,601
# Trainable params: 58,601
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Hafsa\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\Hafsa\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Time took 0.2 min

# %%
import matplotlib.pyplot as plt

labels = ["loss","val_loss"]
for lab in labels:
    plt.plot(hist1.history[lab],label=lab + " model1")
plt.yscale("log")
plt.legend()
plt.show()

# %%
cos=X_train
expected_output=y_train

for layer in model1.layers:
        if 'LSTM' in str(layer):
            weights = layer.get_weights()

            print('Previous memory state states[0] = {}'.format(K.get_value(layer.states[0])))
            print('Previous carry state states[1] = {}'.format(K.get_value(layer.states[1])))

            print('Input')
            print('bias_i = {}'.format(K.get_value(layer.cell.bias_i)))
            print('kernel_i = {}'.format(K.get_value(layer.cell.kernel_i)))
            print('recurrent_kernel_i = {}'.format(K.get_value(layer.cell.recurrent_kernel_i)))

            print('Forget')
            print('bias_f = {}'.format(K.get_value(layer.cell.bias_f)))
            print('kernel_f = {}'.format(K.get_value(layer.cell.kernel_f)))
            print('recurrent_kernel_f = {}'.format(K.get_value(layer.cell.recurrent_kernel_f)))

            print('Cell')
            print('bias_c = {}'.format(K.get_value(layer.cell.bias_c)))
            print('kernel_c = {}'.format(K.get_value(layer.cell.kernel_c)))
            print('recurrent_kernel_c = {}'.format(K.get_value(layer.cell.recurrent_kernel_c)))

            print('Output')
            print('bias_o = {}'.format(K.get_value(layer.cell.bias_o)))
            print('kernel_o = {}'.format(K.get_value(layer.cell.kernel_o)))
            print('recurrent_kernel_o = {}'.format(K.get_value(layer.cell.recurrent_kernel_o)))
    # output of the first batch value of the batch after the first fit().
first_batch_element = np.expand_dims(cos[0], axis=1)  # (1, 1) to (1, 1, 1)
print('output = {}'.format(get_LSTM_output([first_batch_element])[0].flatten()))

model.reset_states()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-84f8d21fe984> in <module>
#       6             weights = layer.get_weights()
#       7
# ----> 8             print('Previous memory state states[0] = {}'.format(K.get_value(layer.states[0])))
#       9             print('Previous carry state states[1] = {}'.format(K.get_value(layer.states[1])))
#      10
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in get_value(x)
#    2305         A Numpy array.
#    2306     """
# -> 2307     return x.eval(session=get_session())
#    2308
#    2309
#
# AttributeError: 'NoneType' object has no attribute 'eval'
